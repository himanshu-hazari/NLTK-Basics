# %% [markdown]
# NLTK 3.0, downloadable for free from http://nltk.org/ <br>
# Download the nltk using pip command as well :-

# %%
# !pip install nltk #install the nltk

# %%
import nltk #import the nltk
nltk.download() #to download the data on the machine C:\Users\Himanshu\AppData\Roaming\nltk_data
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.book import * #to load some texts
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# <I>Any time we want to find out about these downloaded texts, we just have to enter their names at the Python prompt</I><br>
# like In[] text1<br>
# <B><H2>concordance view</H2></B><br>
# Shows us every occurrence of a given word, together with some context.

# %%
text2.concordance("monstrous") #each time run import code above to execute this command
#text5.concordance("im")
# Out:
# Displaying 11 of 11 matches:
# . " Now , Palmer , you shall see a monstrous pretty girl ." He immediately went
# your sister is to marry him . I am monstrous glad of it , for then I shall have
# ou may tell your sister . She is a monstrous lucky girl to get him , upon my ho
# k how you will like them . Lucy is monstrous pretty , and so good humoured and
#  Jennings , " I am sure I shall be monstrous glad of Miss Marianne ' s company
#  usual noisy cheerfulness , " I am monstrous glad to see you -- sorry I could n
# t however , as it turns out , I am monstrous glad there was never any thing in
# so scornfully ! for they say he is monstrous fond of her , as well he may . I s
# possible that she should ." " I am monstrous glad of it . Good gracious ! I hav
# thing of the kind . So then he was monstrous happy , and talked on some time ab
# e very genteel people . He makes a monstrous deal of money , and they keep thei

# %% [markdown]
# <H2>To find words in similar range of contexts use .similar.</H2><br> Context is just the words directly on either side of token

# %%
text1.similar("fictitious")
# Out:
# great sea furious swift utmost ignoble

# %% [markdown]
# <H2>common_contexts</H2> allows us to examine just the contexts that are shared by two or more words,

# %%
text2.common_contexts(["monstrous","very"]) #a monstrous pretty , a very pretty
# Out:
# a_pretty am_glad a_lucky is_pretty be_glad

# %% [markdown]
# We can also determine the location of a word in the text: how many words from the beginning it appears.<br> This positional information can be displayed using a <b>Dispersion Plot</b>. <br>Each stripe represents an instance of a word, and each row represents the entire text

# %%
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])

# %% [markdown]
# <H1>Counting Vocabulary</H1>

# %%
set(text3) #To find the unique words in phrase
# Out:
# {'last',
#  'There',
#  'horse',
#  'Should',
#  'olive',
#  'thigh',
#  'reward',
#  'beneath',
#  'withered',
#  'sustained',
#  'anointedst',
#  'foot',
#  'green',
#  'crieth',
#  'thistles',
#  'Hagar',
#  'week',
#  'Heber',
#  'royal',
#  'earrings',
#  'regard',
#  'hold',
#  'heat',
#  'menservants',
#  'Shimron',
#  'summer',
#  'sporting',
#  'sir',
#  'Philistim',
#  'drinketh',
#  'peradventure',
#  'clothes',
#  'nought',
#  'whose',
#  'ceased',
#  'off',
#  'besought',
#  'Ashkenaz',
#  'grace',
#  'another',
#  'even',
#  'good',
#  'Abimelech',
#  'getting',
#  'Timnah',
#  'repented',
#  'Rebek',
#  'roughly',
#  'created',
#  'floc',
#  'unawares',
#  'restore',
#  'Jerah',
#  'Guni',
#  'Behold',
#  'enlarge',
#  'thither',
#  'thus',
#  'speech',
#  'shekel',
#  'wages',
#  'established',
#  'vowedst',
#  'Eliezer',
#  'above',
#  'fo',
#  'Resen',
#  'Kohath',
#  'Isra',
#  'asked',
#  'Hiddekel',
#  'Mezahab',
#  'vail',
#  'clave',
#  'placed',
#  'Cause',
# ...

# %%
sorted(set(text3)) #to sort the text
# Out:
# ['!',
#  "'",
#  '(',
#  ')',
#  ',',
#  ',)',
#  '.',
#  '.)',
#  ':',
#  ';',
#  ';)',
#  '?',
#  '?)',
#  'A',
#  'Abel',
#  'Abelmizraim',
#  'Abidah',
#  'Abide',
#  'Abimael',
#  'Abimelech',
#  'Abr',
#  'Abrah',
#  'Abraham',
#  'Abram',
#  'Accad',
#  'Achbor',
#  'Adah',
#  'Adam',
#  'Adbeel',
#  'Admah',
#  'Adullamite',
#  'After',
#  'Aholibamah',
#  'Ahuzzath',
#  'Ajah',
#  'Akan',
#  'All',
#  'Allonbachuth',
#  'Almighty',
#  'Almodad',
#  'Also',
#  'Alvah',
#  'Alvan',
#  'Am',
#  'Amal',
#  'Amalek',
#  'Amalekites',
#  'Ammon',
#  'Amorite',
#  'Amorites',
#  'Amraphel',
#  'An',
#  'Anah',
#  'Anamim',
#  'And',
#  'Aner',
#  'Angel',
#  'Appoint',
#  'Aram',
#  'Aran',
#  'Ararat',
#  'Arbah',
#  'Ard',
#  'Are',
#  'Areli',
#  'Arioch',
#  'Arise',
#  'Arkite',
#  'Arodi',
#  'Arphaxad',
#  'Art',
#  'Arvadite',
#  'As',
#  'Asenath',
#  'Ashbel',
#  'Asher',
#  'Ashkenaz',
#  'Ashteroth',
#  'Ask',
#  'Asshur',
#  'Asshurim',
#  'Assyr',
#  'Assyria',
# ...

# %%
text3.count("smote") #to count the number of times a word comes in string
# Out:
# 5

# %%
100*(text3.count("the")/len(text3))#percentage of the text is taken up by a specific word
# Out:
# 5.386024483960325

# %% [markdown]
# <h1>Functions</h1>

# %%
def perctentage(count,total):# function defined here, : marks the end of def statement
    return 100*(count/total)

perctentage(text3.count("the"),len(text3)) #function called here

def lexical_diversity(text): # lexical diversity is defined as the ratio of different unique word stems to the total number of words
     return len(set(text)) / len(text)
    
lexical_diversity(text3)
# Out:
# 0.06230453042623537

# %%
def test(a,b):
    return a*b
test("Y",2)
# Out:
# 'YY'
